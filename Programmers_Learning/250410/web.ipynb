# %%
#requests 모듈 설치
# %pip install requests
# Out:
# ...
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB 3.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/166.4 kB ? eta -:--:--
#    --------------------------------------- 166.4/166.4 kB 10.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/102.8 kB ? eta -:--:--
#    ---------------------------------------- 102.8/102.8 kB 5.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/70.4 kB ? eta -:--:--
#    ---------------------------------------- 70.4/70.4 kB 3.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/128.4 kB ? eta -:--:--
#    ---------------------------------------- 128.4/128.4 kB 7.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\azx49\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
# ...

# %%
#requests 호출하여 
import requests
res = requests.get("https://naver.com")

# %%
# Out:
# {'Content-Type': 'text/html; charset=UTF-8', 'Cache-Control': 'no-cache, no-store, must-revalidate', 'Pragma': 'no-cache', 'x-frame-options': 'DENY', 'x-xss-protection': '1; mode=block', 'strict-transport-security': 'max-age=63072000; includeSubdomains', 'referrer-policy': 'unsafe-url', 'Content-Encoding': 'gzip', 'Server': 'nfront', 'Date': 'Thu, 10 Apr 2025 04:01:24 GMT', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive, Transfer-Encoding', 'Vary': 'Accept-Encoding', 'Set-Cookie': 'PM_CK_loc=bb5d4ed785efdec085c2737d0af75838f96f8d41841837a52d4a8a979f66426f; Expires=Fri, 11 Apr 2025 04:01:23 GMT; Path=/; HttpOnly'}

# %%
#
payload = {"name":"hello?","age":13}
res = requests.post("https://webhook.site/005b494d-c12b-4c47-85be-e68ad9410f43",payload)

# %%
res.status_code
# Out:
# 200

# %%
res.text[:1000]
# Out:
# 'This URL has no default content configured. <a href="https://webhook.site/#!/edit/005b494d-c12b-4c47-85be-e68ad9410f43">Change response in Webhook.site</a>.'
